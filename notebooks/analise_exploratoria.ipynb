# %%
import sys
import os
import pandas as pd
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))
from lisa.data_prepare import DataPrepare
from lisa.utils import generate_filename_map
from lisa.logger import logger

# %%
req_user_stories_dataset = os.path.join("..", "data", "df", "df_user_stories.csv")
raw_text_doc_dir_path = os.path.join("..", "data", "df", "df_req_docs.csv")
req_lists_dir_path = os.path.join("..", "data", "df", "df_requirements.csv")
doc_struct_dir_path = os.path.join("..", "data", "df", "df_metadatas.csv")

# %%
df_user_stories = pd.read_csv(req_user_stories_dataset)
df_req_docs = pd.read_csv(raw_text_doc_dir_path)
df_requirements = pd.read_csv(req_lists_dir_path)
df_metadatas = pd.read_csv(doc_struct_dir_path)

# %%
df_user_stories
# Out:
#                    id                                               text  \
# 0           0-1-1-0.0  As a user of the application, I want to access...
# 1           0-1-1-1.0  As a user of the application, I want to have a...
# 2           0-1-1-2.0  As a user of the application, I want to have a...
# 3           0-1-1-3.0  As a user, I want to have access to detailed c...
# 4           0-1-1-4.0  As a user exploring the application, I want ac...
# ...               ...                                                ...
# 68330  84-3.2.3-9-0.0  As a user, I want the system to issue warnings...
# 68331  84-3.2.3-9-1.0  As a system user, I want the system to issue w...
# 68332  84-3.2.3-9-2.0  As a user of the system, I want the system to ...
# 68333  84-3.2.3-9-3.0  As a user, I want the system to issue warnings...
# 68334  84-3.2.3-9-4.0  As a user, I want the system to issue warnings...
#
#                            type_of_user  \
# 0             a user of the application
# ...

# %%
df_requirements
# Out:
#                id                                               text  \
# 0           0-1-1  The solution should provide detailed context-s...
# 1           0-1-2  The help should be accessible to the users bot...
# 2           0-2-1  The solution should provide an interface for t...
# 3           0-2-2  The solution should send alerts (e.g., email, ...
# 4           0-2-3  The solution should enable the user to track t...
# ...           ...                                                ...
# 12763  85-3.2.1-5  If the ceiling light group in a hallway sectio...
# 12764  85-3.2.2-6  All hardware connections are made according to...
# 12765  85-3.2.2-7  No hazardous conditions for persons, inventory...
# 12766  85-3.2.3-8  The control panels are easy and intuitive to use.
# 12767  85-3.2.3-9  The system issues warnings on unreasonable inp...
#
#       metadata_id  req_doc_id
# 0             0-1           0
# 1             0-1           0
# 2             0-2           0
# ...

# %%
text = "Isabela Yabe Martinez"
index_secao = text.find("Yabe") 
print(index_secao)  # Output: 8
text = text[:index_secao] + text[index_secao+4:]
# Out:
# 8

# %%
df_metadatas
# Out:
#             id                                           doc_name  \
# 0          0-1  E-GOVERNANCE MISSION MODE PROJECT (MMP) CRIME ...
# 1          0-2  E-GOVERNANCE MISSION MODE PROJECT (MMP) CRIME ...
# 2          0-3  E-GOVERNANCE MISSION MODE PROJECT (MMP) CRIME ...
# 3          0-4  E-GOVERNANCE MISSION MODE PROJECT (MMP) CRIME ...
# 4          0-5  E-GOVERNANCE MISSION MODE PROJECT (MMP) CRIME ...
# ...        ...                                                ...
# 4237  85-3.1.2                               light control system
# 4238    85-3.2                               light control system
# 4239  85-3.2.1                               light control system
# 4240  85-3.2.2                               light control system
# 4241  85-3.2.3                               light control system
#
#                           text  req_doc_id
# 0                  Help Module           0
# 1               Support Module           0
# ...
